# %% [markdown]
# # IFC Viewer - Vizualizare Interactivă Completă cu Editare Proprietăți
#
# Acest notebook demonstrează cum să vizualizezi modele IFC cu **UI complet interactiv**,
# folosind biblioteca qto_buccaneer.
#
# ## Caracteristici principale:
# - ✅ **Vizualizare 3D** interactivă cu Plotly (FigureWidget)
# - ✅ **Selectare cu click** direct pe obiectele din scena 3D
# - ✅ **Tabel cu proprietăți QTO** (cantități) pentru toate elementele
# - ✅ **Filtre** pentru Storey și IFC Type
# - ✅ **Control vizibilitate** ierarhic (Storey → Type → Element)
# - ✅ **Tabel editabil de proprietăți** pentru elementul selectat
# - ✅ **Adăugare proprietăți noi** (PropertySet + Proprietate + Valoare)
# - ✅ **Salvare modificări** în modelul IFC (în memorie + export fișier)
# - ✅ **Highlight** pe selectare (element devine galben)
# - ✅ **Configurare culori** din fișier YAML
# - ✅ **Download fișier IFC modificat** (în Google Colab)

# %% [markdown]
# ## 1. Instalare și import
#
# Instalează biblioteca (doar prima dată când rulezi notebook-ul):

# %%
# Instalare bibliotecă din repo-ul de test
# !pip install git+https://github.com/ionuting/qto_test.git@main

# Dependențe pentru Google Colab
# !pip install ifcopenshell plotly ipywidgets scipy pyyaml

# %%
# Activare widgets pentru Google Colab
from google.colab import output
output.enable_custom_widget_manager()

# %% [markdown]
# ## 2. Vizualizare completă cu UI interactiv
#
# Cea mai simplă utilizare - doar 2 linii de cod!
#
# Funcția `visualize_ifc()` afișează automat:
# - **Vizualizare 3D interactivă** cu **selectare prin click** pe obiecte
# - **Dropdown de selecție** rapid pentru elemente
# - **Tabel cu toate elementele** și proprietățile lor QTO
# - **Filtre** pentru Storey și IFC Type
# - **Control de vizibilitate** ierarhic (Storey → Type → Element)
# - **Tabel editabil de proprietăți** când selectezi un element (click 3D sau dropdown)
# - **Adăugare proprietăți noi** la elementul selectat
# - **Salvare modificări** în modelul IFC + export fișier

# %%
from qto_buccaneer import visualize_ifc

# Vizualizare model IFC din URL cu UI complet interactiv
# Include: filtre Storey/Type, tabel cu QTO properties, control vizibilitate, panel proprietăți
url = "https://raw.githubusercontent.com/ionuting/tests/refs/heads/main/output.ifc"
visualize_ifc(url)
# Out:
# Running cells with 'cad_env (Python 3.10.18)' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'conda install -n cad_env ipykernel --update-deps --force-reinstall'

# %% [markdown]
# ### Cum să folosești UI-ul interactiv:
#
# 1. **Vizualizare 3D + Selectare prin Click**:
#    - Rotește, zoom, pan în modelul 3D
#    - **Click pe orice obiect** din scena 3D pentru a-l selecta (devine galben)
#    - Sau folosește **dropdown-ul de selecție** sub viewer
# 2. **Tabel Overview**:
#    - Vezi toate elementele și proprietățile lor QTO
#    - Click pe un rând în tabel pentru a selecta elementul
# 3. **Filtre**:
#    - Selectează Storey (nivel/etaj) din dropdown
#    - Selectează IFC Type (IfcWall, IfcSlab, etc.) din dropdown
#    - Click "Apply Filters" pentru a actualiza vizualizarea
# 4. **Editare Proprietăți** (panoul din dreapta):
#    - Selectează un element → apare tabelul editabil cu toate proprietățile
#    - **Modifică valori** direct în câmpurile text
#    - **Adaugă proprietăți noi**: completează PropertySet, Property name, Value și click "➕ Add"
#    - Click **"💾 Save to IFC Model"** pentru a salva modificările în memorie
#    - Click **"💾 Save IFC File"** pentru a exporta fișierul IFC modificat
# 5. **Control Vizibilitate**:
#    - Expand acordeoanele pentru a vedea elementele pe nivele
#    - Checkbox individual pentru show/hide fiecare element
#    - "Select All" pentru a activa/dezactiva toate elementele dintr-un tip

# %% [markdown]
# ## 3. Funcționalități UI Interactiv + Editare
#
# UI-ul include:
# - **Selectare 3D**: Click direct pe obiecte în scena Plotly 3D
# - **Dropdown selecție**: Selectează rapid un element din lista elementelor vizibile
# - **Filtre**: Selectează Storey și IFC Type pentru a filtra elementele
# - **Tabel interactiv**: Afișează toate elementele cu proprietățile lor QTO (cantități)
# - **Tabel editabil proprietăți**: Modifică și adaugă proprietăți la elementul selectat
# - **Salvare IFC**: Salvează modificările în modelul IFC și exportă fișierul
# - **Control vizibilitate**: Acordeoane ierarhice pentru show/hide pe element
# - **Highlight**: Elementele selectate devin galbene în vizualizarea 3D
#
# Poți folosi fișierul YAML pentru a controla culorile elementelor IFC:

# %%
# Cu configurare culori personalizată
visualize_ifc(
    ifc_source=url,
    color_config_path="path/to/your/abstractBIM_plots_config.yaml",
    verbose=True  # Afișează informații detaliate despre procesare
)

# %% [markdown]
# ## 4. Vizualizare doar 3D (fără UI interactiv)
#
# Dacă vrei doar vizualizarea 3D fără filtre, tabel și controale:

# %%
# Doar viewer 3D, fără UI
viz, hierarchy = visualize_ifc(
    ifc_source=url,
    show_ui=False
)

# Poți accesa datele procesate
print(f"Nivele găsite: {list(hierarchy.keys())}")

# %% [markdown]
# ## 5. Vizualizare fișier local din Google Drive
#
# Dacă ai modelul în Google Drive:

# %%
# Montează Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Vizualizare model din Google Drive
local_path = '/content/drive/My Drive/path/to/your/model.ifc'
visualize_ifc(local_path)

# %% [markdown]
# ## Caracteristici UI Interactiv + Editare Proprietăți
#
# ### Selectare 3D cu Click
# - **Click** direct pe orice obiect din scena Plotly 3D
# - Elementul selectat devine **galben** instant
# - Panelul editabil de proprietăți se deschide automat în dreapta
# - Alternativ, folosește **dropdown-ul de selecție** pentru a alege un element
#
# ### Tabel Editabil de Proprietăți
# Când selectezi un element, panelul din dreapta afișează:
# - **Toate PropertySet-urile** (Pset_*, etc.) cu proprietățile editabile
# - **Toate IfcElementQuantity** (Qto_*) cu cantitățile editabile
# - **Proprietăți IfcCovering** pentru pereți (read-only)
#
# ### Adăugare Proprietăți Noi
# - Completează **PropertySet name** (ex: `Pset_Custom`, `Pset_CostData`)
# - Completează **Property name** (ex: `CostPerUnit`, `Material`)
# - Completează **Value** (ex: `150.00`, `Beton C25/30`)
# - Click **"➕ Add"** — proprietatea apare marcată cu ✨ New
# - Click **"💾 Save to IFC Model"** pentru a o persista
#
# ### Salvare Modificări
# - **"💾 Save to IFC Model"**: Salvează toate modificările în modelul IFC din memorie
#   - Actualizează proprietățile existente (păstrând tipul original: IfcReal, IfcText, etc.)
#   - Creează PropertySet-uri noi pentru proprietăți noi
#   - Afișează numărul de proprietăți modificate și adăugate
# - **"💾 Save IFC File"**: Exportă modelul IFC modificat ca fișier
#   - În Google Colab: fișierul se descarcă automat
#   - Local: fișierul se salvează pe disc
#
# ### Tabel cu Proprietăți QTO
# Tabelul overview afișează automat toate proprietățile de cantități (QTO):
# - `Qto_WallBaseQuantities`: NetSideArea, GrossVolume, etc.
# - `Qto_SlabBaseQuantities`: NetArea, GrossArea, Perimeter, etc.
# - `Qto_WindowBaseQuantities`: Width, Height, Area, etc.
#
# ### Control Vizibilitate
# - **Acordeoane pe niveluri**: Storey → IFC Type → Elemente individuale
# - **Select All**: Checkbox pentru show/hide toate elementele din fiecare tip
# - **Expand/Collapse All**: Butoane pentru a deschide/închide toate acordeoanele
#
# ### Filtre
# - **Filter by Storey**: Afișează doar elementele dintr-un nivel
# - **Filter by IFC Type**: Afișează doar un tip de element (IfcWall, IfcSlab, etc.)
# - Tabelul, vizualizarea 3D și dropdown-ul de selecție se actualizează automat
#
# ## Notă despre culori
#
# Biblioteca suportă maparea automată a culorilor pe tipuri IFC din fișierul YAML.
# De exemplu:
#
# ```yaml
# plots:
#   exterior_view:
#     elements:
#       - name: "Walls"
#         filter: "type=IfcWall"
#         color: "black"
#       - name: "Windows"
#         filter: "type=IfcWindow"
#         color: "#0000FF"
# ```
#
# Toate elementele `IfcWall` vor fi negre, `IfcWindow` vor fi albastre, etc.
